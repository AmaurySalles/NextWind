# %%
# %reload_ext autoreload
# %autoreload 2
from projectwind.data import get_data
from projectwind.data import get_samples
from projectwind.data import get_clean_sequences

# %%
all_WTG_data, fit_data = get_data()
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
all_WTG_data
# Out:
# {0:                      Misalignment    Power  Nacelle Orientation  Rotor Speed  \
#  Fecha
#  2019-05-01 00:00:00        4.0550  1159.76                179.0      11.3798
#  2019-05-01 00:10:00        5.9857  1103.73                179.0      11.2373
#  2019-05-01 00:20:00        4.2801  1119.01                179.0      11.3240
#  2019-05-01 00:30:00        3.7854  1281.76                179.0      11.8430
#  2019-05-01 00:40:00        2.2943  1121.60                179.0      11.3040
#  ...                           ...      ...                  ...          ...
#  2021-09-30 23:10:00        2.5614    52.39                342.0       8.1948
#  2021-09-30 23:20:00        4.7241   159.25                342.0       8.1930
#  2021-09-30 23:30:00      356.7216   246.98                342.0       8.1955
#  2021-09-30 23:40:00      354.9347    88.34                342.0       8.1912
#  2021-09-30 23:50:00      359.4861    90.62                342.0       8.1938
#
# ...

# %%
samples = get_samples(day_length=5.5, number_of_subsamples=100, acceptable_level_of_missing_values=0.05)
# Out:
# 0
#         Misalignment    Power  Nacelle Orientation  Rotor Speed  Wind Speed  \
# 0             4.0550  1159.76                179.0      11.3798      7.9142
# 1             5.9857  1103.73                179.0      11.2373      7.6762
# 2             4.2801  1119.01                179.0      11.3240      7.9582
# 3             3.7854  1281.76                179.0      11.8430      8.3035
# 4             2.2943  1121.60                179.0      11.3040      7.9395
# ...              ...      ...                  ...          ...         ...
# 122865        2.5614    52.39                342.0       8.1948      3.8080
# 122866        4.7241   159.25                342.0       8.1930      4.4738
# 122867      356.7216   246.98                342.0       8.1955      5.3445
# 122868      354.9347    88.34                342.0       8.1912      4.3468
# 122869      359.4861    90.62                342.0       8.1938      4.1622
#
#         Blade Pitch
# 0           -0.4838
# ...

# %%
samples[0].shape
# Out:
# (4, 720, 6)

# %%
samples[1].shape
# Out:
# (4, 72)

# %%
from Prophet import prophet
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [31], in <module>
# ----> 1 from Prophet import prophet
#
# ModuleNotFoundError: No module named 'Prophet'
