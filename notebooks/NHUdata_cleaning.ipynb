# %%
import pandas as pd
import numpy as np
import os

# %%
# Take the parent dirname for the raw data
parentdir = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
rawdir = os.path.join(parentdir,"raw_data")
rawdir
# Out:
# '/Users/nicolashenriquezurzua/code/AmaurySALLES/projectwind/raw_data'

# %%
os.path.join(rawdir,"A01.csv")
# Out:
# '/Users/nicolashenriquezurzua/code/AmaurySALLES/projectwind/raw_data/A01.csv'

# %%
def concatenate_df():
    # Take the parent dirname for the raw data
    parentdir = os.path.dirname(os.path.dirname(os.path.abspath("__file__")))
    rawdir = os.path.join(parentdir,"raw_data")
    
    # init global DF
    globalDF = pd.read_csv(os.path.join(rawdir,"A01.csv"))
    globalDF["Turbine_id"] = 1
    
    # loop over the CSVs
    for i in range(2,26):
    # CSV file name    
        if i <10:
            file="A0"+str(i)+".csv"
        else:
            file="A"+str(i)+".csv"
        df = pd.read_csv(os.path.join(rawdir,file))
        # add an ID for each turbine
        df["Turbine_id"] = i
        
        #concatenate df
        globalDF = pd.concat((globalDF,df),ignore_index=True)
    return globalDF

# %%
a=concatenate_df()
a
# Out:
#                   Fecha  \
# 0        01/05/19 00:00
# 1        01/05/19 00:10
# 2        01/05/19 00:20
# 3        01/05/19 00:30
# 4        01/05/19 00:40
# ...                 ...
# 3084070  30/09/21 23:10
# 3084071  30/09/21 23:20
# 3084072  30/09/21 23:30
# 3084073  30/09/21 23:40
# 3084074  30/09/21 23:50
#
#          Desalineación Nacelle y Dirección de Viento Media 10M\n(°)  \
# 0                                                   358.07
# 1                                                     2.63
# 2                                                     1.85
# 3                                                   355.89
# 4                                                   358.16
# ...                                                    ...
# 3084070                                               5.90
# 3084071                                               4.21
# 3084072                                               5.60
# 3084073                                             355.48
# 3084074                                             354.71
#
#          Media de Potencia Activa 10M\n(kW)  Posición Nacelle Media 10M\n(°)  \
# 0                                   1357.58                           194.00
# 1                                   1252.87                           194.00
# 2                                   1661.33                           194.00
# 3                                   1863.22                           194.00
# 4                                   1942.12                           194.00
# ...                                     ...                              ...
# 3084070                               16.59                            96.64
# 3084071                               94.53                           113.00
# 3084072                              138.04                           113.00
# 3084073                               59.68                           113.00
# 3084074                               37.11                           113.00
#
#          Velocidad Rotor Media 10M\n(rpm)  Velocidad Viento Media 10M\n(m/s)  \
# 0                                   11.94                               8.80
# 1                                   11.58                               8.13
# 2                                   12.60                               9.09
# 3                                   12.87                              10.15
# 4                                   12.97                              10.04
# ...                                   ...                                ...
# 3084070                              8.19                               3.41
# 3084071                              8.19                               3.91
# 3084072                              8.19                               4.35
# 3084073                              8.20                               4.10
# 3084074                              8.20                               3.86
#
#          Ángulo Pitch Media 10M\n(°)  Turbine_id
# 0                              -0.79           1
# 1                              -0.42           1
# 2                              -0.36           1
# 3                               0.64           1
# 4                               0.42           1
# ...                              ...         ...
# 3084070                         2.98          25
# 3084071                         2.49          25
# 3084072                         1.92          25
# 3084073                         2.29          25
# 3084074                         2.57          25
#
# [3084075 rows x 8 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
a.describe()
# Out:
#        Desalineación Nacelle y Dirección de Viento Media 10M\n(°)  \
# count                                         3084050.00
# mean                                              168.44
# std                                               173.32
# min                                                 0.00
# 25%                                                 2.75
# 50%                                                25.67
# 75%                                               357.09
# max                                               360.00
#
#        Media de Potencia Activa 10M\n(kW)  Posición Nacelle Media 10M\n(°)  \
# count                          3084075.00                       3083950.00
# mean                               731.86                           145.57
# std                                654.60                            52.72
# min                                -27.57                             0.00
# 25%                                161.79                           114.00
# 50%                                564.36                           140.00
# 75%                               1179.80                           180.00
# max                               2119.69                           360.00
#
#        Velocidad Rotor Media 10M\n(rpm)  Velocidad Viento Media 10M\n(m/s)  \
# count                        3084025.00                         3084050.00
# mean                               9.14                               6.49
# std                                3.16                               2.61
# min                                0.00                               0.14
# 25%                                8.19                               4.70
# 50%                                9.14                               6.43
# 75%                               11.46                               8.26
# max                               13.13                              20.55
#
#        Ángulo Pitch Media 10M\n(°)  Turbine_id
# count                   3084000.00  3084075.00
# mean                          6.57       13.00
# std                          19.87        7.21
# min                          -1.00        1.00
# 25%                          -0.51        7.00
# 50%                           0.10       13.00
# 75%                           2.44       19.00
# max                          87.30       25.00

# %%
a["delta"] = abs(a['Desalineación Nacelle y Dirección de Viento Media 10M\n(°)']-a['Ángulo Pitch Media 10M\n(°)'])

# %%
a.columns
# Out:
# Index(['Fecha', 'Desalineación Nacelle y Dirección de Viento Media 10M\n(°)',
#        'Media de Potencia Activa 10M\n(kW)', 'Posición Nacelle Media 10M\n(°)',
#        'Velocidad Rotor Media 10M\n(rpm)', 'Velocidad Viento Media 10M\n(m/s)',
#        'Ángulo Pitch Media 10M\n(°)', 'Turbine_id', 'delta'],
#       dtype='object')

# %%
a
# Out:
#                   Fecha  \
# 0        01/05/19 00:00
# 1        01/05/19 00:10
# 2        01/05/19 00:20
# 3        01/05/19 00:30
# 4        01/05/19 00:40
# ...                 ...
# 3084070  30/09/21 23:10
# 3084071  30/09/21 23:20
# 3084072  30/09/21 23:30
# 3084073  30/09/21 23:40
# 3084074  30/09/21 23:50
#
#          Desalineación Nacelle y Dirección de Viento Media 10M\n(°)  \
# 0                                                   358.07
# 1                                                     2.63
# 2                                                     1.85
# 3                                                   355.89
# 4                                                   358.16
# ...                                                    ...
# 3084070                                               5.90
# 3084071                                               4.21
# 3084072                                               5.60
# 3084073                                             355.48
# 3084074                                             354.71
#
#          Media de Potencia Activa 10M\n(kW)  Posición Nacelle Media 10M\n(°)  \
# 0                                   1357.58                           194.00
# 1                                   1252.87                           194.00
# 2                                   1661.33                           194.00
# 3                                   1863.22                           194.00
# 4                                   1942.12                           194.00
# ...                                     ...                              ...
# 3084070                               16.59                            96.64
# 3084071                               94.53                           113.00
# 3084072                              138.04                           113.00
# 3084073                               59.68                           113.00
# 3084074                               37.11                           113.00
#
#          Velocidad Rotor Media 10M\n(rpm)  Velocidad Viento Media 10M\n(m/s)  \
# 0                                   11.94                               8.80
# 1                                   11.58                               8.13
# 2                                   12.60                               9.09
# 3                                   12.87                              10.15
# 4                                   12.97                              10.04
# ...                                   ...                                ...
# 3084070                              8.19                               3.41
# 3084071                              8.19                               3.91
# 3084072                              8.19                               4.35
# 3084073                              8.20                               4.10
# 3084074                              8.20                               3.86
#
#          Ángulo Pitch Media 10M\n(°)  Turbine_id  delta
# 0                              -0.79           1 358.87
# 1                              -0.42           1   3.05
# 2                              -0.36           1   2.21
# 3                               0.64           1 355.25
# 4                               0.42           1 357.74
# ...                              ...         ...    ...
# 3084070                         2.98          25   2.93
# 3084071                         2.49          25   1.72
# 3084072                         1.92          25   3.68
# 3084073                         2.29          25 353.19
# 3084074                         2.57          25 352.13
#
# [3084075 rows x 9 columns]

# %%
a.isna().sum()
# Out:
# Fecha                                                           0
# Desalineación Nacelle y Dirección de Viento Media 10M\n(°)     25
# Media de Potencia Activa 10M\n(kW)                              0
# Posición Nacelle Media 10M\n(°)                               125
# Velocidad Rotor Media 10M\n(rpm)                               50
# Velocidad Viento Media 10M\n(m/s)                              25
# Ángulo Pitch Media 10M\n(°)                                    75
# Turbine_id                                                      0
# dtype: int64

# %%
# Out:
# A01.csv
